# %% [markdown]
# # Shorten URL

# %%
url = 'https://www.google.com/search?q=chatgpt'

# %%
import string

base_chars = string.ascii_letters + string.digits 

base_chars
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

# %%
base = len(base_chars)
id = 1

num = id

rem = id % base
num = num // base

div, rem
# Out:
# (0, 1)

# %%
code = [base_chars[rem]]
code, url
# Out:
# (['b'], 'https://www.google.com/search?q=chatgpt')

# %%
url_map = {}

url_map[code] = url

short_url = f"https:://short.ly/{code}"
id += 1
short_url
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 url_map = {}
# ----> 3 url_map[code] = url
#       5 short_url = f"https:://short.ly/{code}"
#       6 id += 1
#
# TypeError: unhashable type: 'list'
